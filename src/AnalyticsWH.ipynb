# %%
import sys
import os

# fix path (important for notebook)
sys.path.append(os.getcwd())

# core libraries
import pandas as pd
import psycopg2

# your modules
from extract import extract_data
from transform import transform_data
from load import load_data
from ddl import run_ddl
from initial_load import initial_load

# %%
df  = extract_data()
# Out:
# ✅ Extract successful: 311 rows, 36 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   employee_name               311 non-null    object
#  1   empid                       311 non-null    int64
#  2   marriedid                   311 non-null    int64
#  3   maritalstatusid             311 non-null    int64
#  4   genderid                    311 non-null    int64
#  5   empstatusid                 311 non-null    int64
#  6   deptid                      311 non-null    int64
#  7   perfscoreid                 311 non-null    int64
#  8   fromdiversityjobfairid      311 non-null    int64
#  9   salary                      311 non-null    int64
#  10  termd                       311 non-null    int64
#  11  positionid                  311 non-null    int64
#  12  position                    311 non-null    object
#  13  state                       311 non-null    object
#  14  zip                         311 non-null    int64
#  15  dob                         311 non-null    datetime64[ns]
#  16  sex                         311 non-null    object
#  17  maritaldesc                 311 non-null    object
#  18  citizendesc                 311 non-null    object
#  19  hispaniclatino              311 non-null    object
#  20  racedesc                    311 non-null    object
#  21  dateofhire                  311 non-null    datetime64[ns]
#  22  dateoftermination           104 non-null    datetime64[ns]
#  23  termreason                  311 non-null    object
#  24  employmentstatus            311 non-null    object
#  25  department                  311 non-null    object
#  26  managername                 311 non-null    object
#  27  managerid                   303 non-null    float64
#  28  recruitmentsource           311 non-null    object
#  29  performancescore            311 non-null    object
#  30  engagementsurvey            311 non-null    float64
#  31  empsatisfaction             311 non-null    int64
#  32  specialprojectscount        311 non-null    int64
#  33  lastperformancereview_date  311 non-null    datetime64[ns]
#  34  dayslatelast30              311 non-null    int64
#  35  absences                    311 non-null    int64
# dtypes: datetime64[ns](4), float64(2), int64(16), object(14)
# memory usage: 87.6+ KB

# %%
run_ddl(reset=True)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 run_ddl(reset=True)
#
# File f:\Dibimbing\Assignnment\Day29\Warehouse\ddl.py:154, in run_ddl(reset)
#     153 def run_ddl(reset=False):
# --> 154     conn = create_connection()
#     155     cursor = conn.cursor()
#     157     try:
#
# File f:\Dibimbing\Assignnment\Day29\Warehouse\ddl.py:13, in create_connection()
#      12 def create_connection():
# ---> 13     return psycopg2.connect(
#      14         host=DB_HOST,
#      15         port=DB_PORT,
#      16         dbname=DB_NAME,
#      17         user=DB_USER,
#      18         password=DB_PASSWORD
#      19     )
#
# File d:\Anaconda\Lib\site-packages\psycopg2\__init__.py:135, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     132     kwasync['async_'] = kwargs.pop('async_')
#     134 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     136 if cursor_factory is not None:
#     137     conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "localhost" (::1), port 5432 failed: FATAL:  database "hr_warehouse" does not exist
